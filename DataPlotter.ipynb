# %%
import serial
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import timeit

L = []
i=0
ser = serial.Serial('/dev/ttyACM1', 115200)
print(ser)
print("starting!")
start = timeit.default_timer()
while(i<1000):
    
    data = ser.readline().decode("utf-8")
    data=data[0:][:-2]
    L.append(data)
    i=i+1
    


stop = timeit.default_timer()
print("Done! Time elapsed: ", stop - start)
# Out:
# Serial<id=0x7fb8dce32d68, open=True>(port='/dev/ttyACM1', baudrate=115200, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False)
# starting!
# Done! Time elapsed:  22.571020953997504

# %%
len(L)
# Out:
# 1000

# %%
A = np.array([float(elem) for elem in L[1:]])
print(len(A))
x = np. linspace(0,999,999)


plt.figure(figsize=(20,5))
plt.title('1000 amostras recolhidas')
plt.xlabel('amostras')
plt.plot(x,A)
# Out:
# 999

# %%
print()
#L_array = np.array([int(elem) for elem in L])
#print(L_array)
#print(len(L_array))
#plt.plot(L_array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-ed68bacc4a43> in <module>
# ----> 1 L_array = np.array([int(elem) for elem in L])
#       2 print(L_array)
#       3 print(len(L_array))
#       4 #plt.plot(L_array)
#
# <ipython-input-51-ed68bacc4a43> in <listcomp>(.0)
# ----> 1 L_array = np.array([int(elem) for elem in L])
#       2 print(L_array)
#       3 print(len(L_array))
#       4 #plt.plot(L_array)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(0, 4), ylim=(-2, 2))
line, = ax.plot([], [], lw=3)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)


#anim.save('sine_wave.gif', writer='imagemagick')
